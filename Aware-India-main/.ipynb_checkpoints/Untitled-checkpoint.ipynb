# %%
from newsapi import NewsApiClient

newsapi = NewsApiClient(api_key='1feb0a965fc64bdf877c74c57e5de45f')
top_headlines = newsapi.get_top_headlines('https://newsapi.org/v2/top-headlines?country=us&apiKey=1feb0a965fc64bdf877c74c57e5de45f')
top_headlines
# sources = newsapi.get_sources()
# sources
# Out:
# {'status': 'ok', 'totalResults': 0, 'articles': []}

# %%
from newsapi import NewsApiClient

# Init
newsapi = NewsApiClient(api_key='1feb0a965fc64bdf877c74c57e5de45f')

# /v2/top-headlines
top_headlines = newsapi.get_top_headlines(q='crime',
                                          category='general',
                                          language='en',
                                          country='in')

# /v2/everything
all_articles = newsapi.get_everything(q='crime',
                                      sources='the-times-of-india',
                                      from_param='2024-08-15',
                                      to='2024-09-12',
                                      language='en',
                                      sort_by='relevancy',
                                      page=3)

# /v2/top-headlines/sources
sources = newsapi.get_sources()
# Out:
# ---------------------------------------------------------------------------
# NewsAPIException                          Traceback (most recent call last)
# Cell In[1], line 13
#       7 top_headlines = newsapi.get_top_headlines(q='crime',
#       8                                           category='general',
#       9                                           language='en',
#      10                                           country='in')
#      12 # /v2/everything
# ---> 13 all_articles = newsapi.get_everything(q='crime',
#      14                                       sources='the-times-of-india',
#      15                                       from_param='2024-08-15',
#      16                                       to='2024-09-12',
#      17                                       language='en',
#      18                                       sort_by='relevancy',
#      19                                       page=3)
#      21 # /v2/top-headlines/sources
# ...

# %%
top_headlines
# Out:
# {'status': 'ok', 'totalResults': 0, 'articles': []}

# %%
all_articles
# Out:
# {'status': 'ok',
#  'totalResults': 519,
#  'articles': [{'source': {'id': 'the-times-of-india',
#     'name': 'The Times of India'},
#    'author': 'PTI',
#    'title': "Kerala govt orders 'space audit' in state medical colleges to ensure employee safety",
#    'description': "Kerala's government initiated a space audit in medical colleges for employee safety after protests against a doctor's rape and murder in Kolkata. Health Minister Veena George mandated security measures like mock drills, CCTV installation, and the Code Gray pr…",
#    'url': 'https://economictimes.indiatimes.com/news/india/kerala-govt-orders-space-audit-in-state-medical-colleges-to-ensure-employee-safety/articleshow/112649791.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-112649819,width-1200,height-630,imgsize-27198,overlay-economictimes/photo.jpg',
#    'publishedAt': '2024-08-20T09:09:12Z',
# ...

# %%
pip install newsdataapi
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from newsdataapi import NewsDataApiClient

# API key authorization, Initialize the client with your API key

api = NewsDataApiClient(apikey="pub_535390b3bc18b57bfa3632b23c4bb62947d99")

# You can pass empty or with request parameters {ex. (country = "us")}

response = api.news_api(country = "in" ,language='en,hi,gu' , category='crime',size=5)
# Out:
# C:\Users\ferha\AppData\Local\Temp\ipykernel_20548\1295415345.py:9: DeprecationWarning: This method is deprecated and will be removed in upcoming updates, Instead use latest_api()
#   response = api.news_api(country = "in" ,language='en' , category='crime',size=5)

# %%
response['results'][4]
# Out:
# {'article_id': 'e3d1f0d0d5255c03152c8f13d0552c8f',
#  'title': '‘Heavens won’t fall if the demolitions are stopped for a week’: SC pauses bulldozer action in the country till 1st October, read which exceptions are allowed',
#  'link': 'https://www.opindia.com/2024/09/sc-pauses-bulldozer-action-in-the-country-till-1st-october-read-which-exceptions-are-allowed/',
#  'keywords': ['bulldozer action',
#   'featured',
#   'demolition',
#   'illegal encroachment',
#   'supreme court',
#   "editor's picks",
#   'news reports',
#   'law'],
#  'creator': ['OpIndia Staff'],
#  'video_url': None,
#  'description': 'The Supreme Court declared that it will create guidelines governing the when and how of property demolition.',
#  'content': 'ONLY AVAILABLE IN PAID PLANS',
#  'pubDate': '2024-09-17 10:35:39',
#  'pubDateTZ': 'UTC',
#  'image_url': 'https://i0.wp.com/www.opindia.com/wp-content/uploads/2024/09/supreme-court-5.jpg?fit=696%2C398&ssl=1',
#  'source_id': 'opindia',
# ...

# %%
import pandas as pd

df1=pd.read_csv('backend/Crime/csv/crime_dataset_india.csv')
df1
# Out:
#        Report Number     Date Reported Date of Occurrence Time of Occurrence  \
# 0                  1  02-01-2020 00:00   01-01-2020 00:00   01-01-2020 01:11
# 1                  2  01-01-2020 19:00   01-01-2020 01:00   01-01-2020 06:26
# 2                  3  02-01-2020 05:00   01-01-2020 02:00   01-01-2020 14:30
# 3                  4  01-01-2020 05:00   01-01-2020 03:00   01-01-2020 14:46
# 4                  5  01-01-2020 21:00   01-01-2020 04:00   01-01-2020 16:51
# ...              ...               ...                ...                ...
# 40155          40156  01-08-2024 16:00   07-31-2024 03:00   31-07-2024 05:05
# 40156          40157  31-07-2024 14:00   07-31-2024 04:00   31-07-2024 04:14
# 40157          40158  02-08-2024 03:00   07-31-2024 05:00   31-07-2024 21:33
# 40158          40159  01-08-2024 19:00   07-31-2024 06:00   31-07-2024 11:05
# 40159          40160  31-07-2024 17:00   07-31-2024 07:00   31-07-2024 17:19
#
# ...

# %%
df2=pd.read_csv("backend/Crime/csv/Indian Cities Database.csv")
df2
# Out:
#              City        Lat       Long country iso2           State
# 0          Abohar  30.144533  74.195520   India   IN          Punjab
# 1        Adilabad  19.400000  78.310000   India   IN       Telangana
# 2        Agartala  23.836049  91.279386   India   IN         Tripura
# 3            Agra  27.187935  78.003944   India   IN   Uttar Pradesh
# 4      Ahmadnagar  19.094571  74.738432   India   IN     Maharashtra
# ..            ...        ...        ...     ...  ...             ...
# 208  Vizianagaram  18.113290  83.397743   India   IN  Andhra Pradesh
# 209      Warangal  17.978423  79.600209   India   IN       Telangana
# 210    Jorapokhar  23.700000  86.412670   India   IN       Jharkhand
# 211  Brajrajnagar  21.820000  83.920000   India   IN          Odisha
# 212       Talcher  20.950000  85.230000   India   IN          Odisha
#
# [213 rows x 6 columns]

# %%
merged_df = pd.merge(df1, df2[['City', 'State']], on='City', how='left')

# Save the updated DataFrame to a new CSV file
merged_df.to_csv('updated_df1.csv', index=False)

# %%
merged_df.isna().sum()
# Out:
# Report Number             0
# Date Reported             0
# Date of Occurrence        0
# Time of Occurrence        0
# City                      0
# Crime Code                0
# Crime Description         0
# Victim Age                0
# Victim Gender             0
# Weapon Used            5790
# Crime Domain              0
# Police Deployed           0
# Case Closed               0
# Date Case Closed      20098
# State                 11123
# dtype: int64
